# %% [markdown]
# Q1. Write a Python program to store your:
# •	Name
# •	Age
# •	City
# Then print all values.

# %%
name = "Areeha"
age = 23
city = "gujranwala"
print("My name is", name, "and my age is ",age,"and my city is ", city)
# Out:
# My name is Areeha and my age is  23 and my city is  gujranwala

# %% [markdown]
# Q2. Write a program to check whether a number entered by the user is positive, negative, or zero.

# %%
num = float(input("Enter a number: "))
if num > 0:
    print("Positive Number")
elif num < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Positive Number

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %%
marks = float(input("Enter student marks: "))
if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible to Vote")
# Out:
# Eligible to Vote

# %%
temperature = float(input("Enter temperature: "))
if temperature > 35:
    print("Hot")
elif temperature >= 20 and temperature <= 35:
    print("Normal")
else:
    print("Cold")
# Out:
# Hot

# %%
name = input("Enter student name: ")
age = int(input("Enter age: "))
marks = float(input("Enter marks: "))
enrolled = input("Is student enrolled? (True/False): ")

if enrolled == "True":
    enrolled = True
else:
    enrolled = False
if marks >= 50 and age >= 18:
    result = "PASS and eligible for higher studies"
elif marks >= 80 or enrolled == True:
    result = "EXCELLENT / Active Participant"
else:
    result = "Student needs improvement"
print("Student Record")
print("Name:", name)
print("Age:", age)
print("Marks:", marks)
print("Enrolled:", enrolled)
print("Result:", result)
# Out:
# Student Record
# Name: areeha
# Age: 23
# Marks: 200.0
# Enrolled: False
# Result: PASS and eligible for higher studies
